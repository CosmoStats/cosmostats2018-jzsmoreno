# %% [markdown]
# # Primer notebook del curso
# ## Contiene instrucciones básicas de Python

# %%
# Importando librerías a usar 
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Graficando la función $y=x^2$

# %%
x=np.linspace(0,5)
y=x**2
plt.plot(x,y)
plt.show()
